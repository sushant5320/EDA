# %%
nums = [1, 2, 2, 3, 3, 3]
k = 2
d = {i:i.count()  for i in nums}
d
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 nums = [1, 2, 2, 3, 3, 3]
#       2 k = 2
# ----> 3 d = {i:i.count()  for i in nums}
#       4 d
#
# AttributeError: 'int' object has no attribute 'count'

# %%
a = 5
a.

# %%
a.
